# %% [markdown]
# # Analysis and modelling of TV shows IMDB ranking (MVP)
# Based on data from TV shows released in 2019-2021, with at least 1000 votes

# %% [markdown]
# ![imdb_hist_plot-2.png](attachment:imdb_hist_plot-2.png)

# %% [markdown]
# Considered IMDB scores are not uniformly distributed, average score is between 6-8.

# %% [markdown]
# ![imdb_pair_plot.png](attachment:imdb_pair_plot.png)

# %% [markdown]
# ![imdb_heat_map-2.png](attachment:imdb_heat_map-2.png)

# %% [markdown]
# Initial pairplot and heatmap for continuous data may suggest correlation of IMDB score with episodes number, runtime or number of main star’s awards.
