# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

# %matplotlib inline

# %%
#Import of IMDB data scraped in previous notebook
df = pd.read_pickle("./shows.pkl")

# %%
df.columns
# Out:
# Index(['link', 'imdb_rating', 'title', 's01_episodes', 'avg_runtime', 'genres',
#        'rel_date', 'certification', 'origin', 'company', 'creators',
#        'creators_a', 'stars', 'stars_a'],
#       dtype='object')

# %% [markdown]
# ### data cleaning, processing, and initial exploration

# %% [markdown]
# GENRES

# %%
genres_l = set(df.genres.sum())

# %%
def m(x):
    if i in x:
        return 1
    else:
        return 0
    
for i in genres_l:
    df[i] = df.genres.apply(m)

# %%
df[['imdb_rating'] + list(genres_l)].corr().iloc[:,0]
# Out:
# imdb_rating    1.000000
# Thriller       0.034059
# Music          0.014045
# Comedy         0.022244
# Biography      0.067982
# Adventure     -0.001700
# Horror        -0.100276
# Documentary    0.027008
# Western        0.036265
# Sci-Fi        -0.105571
# Romance        0.045513
# Short         -0.053239
# Mystery       -0.006094
# Action         0.000980
# Family        -0.048417
# Game-Show     -0.053298
# News           0.069006
# Talk-Show     -0.009340
# War            0.014827
# Crime          0.038813
# History        0.051376
# Drama          0.033611
# Reality-TV    -0.082501
# Animation      0.038486
# Musical       -0.054243
# Sport          0.071994
# Fantasy        0.004190
# Name: imdb_rating, dtype: float64

# %%
df.rename(columns={"Talk-Show": "Talk_Show", "Sci-Fi": "Sci_Fi", "Game-Show": "Game_Show", "Reality-TV":"Reality_TV"}, inplace=True)

# %%
df['genres_n'] = (df.genres.apply(lambda x: len(x)))

# %% [markdown]
# RELEASE DATE

# %%
#Create a column for the release month of the TV show
df['rel_month']= pd.DatetimeIndex(df['rel_date']).month

# %% [markdown]
# CERTIFICATION

# %%
#after exploration looks like over 457 of the shows have no certification info, still will keep that column to anlyse shows that have certification info
df.loc[df.certification.apply(len) > 7, 'certification'] = "0"
df.loc[df.certification == '', 'certification'] = "0"

#Unification of the certification categories
df.certification.replace({'TV-Y7': 'TV-PG', 'TV-G': 'TV-PG', 'TV-Y': 'TV-PG', 'PG': 'TV-PG', 'PG-13': 'TV-14'}, inplace=True)

df.certification.value_counts()
# Out:
# 0        456
# TV-MA    446
# TV-14    314
# TV-PG    139
# Name: certification, dtype: int64

# %%
df['TV_PG'] = (df['certification'] == 'TV-PG').apply(int)
df['TV_14'] = (df['certification'] == 'TV-14').apply(int)
df['TV_MA'] = (df['certification'] == 'TV-MA').apply(int)

# %% [markdown]
# ORIGIN

# %%
#I simplyfy that column to boolean 'made_in_usa'
df.origin.value_counts()
# Out:
# United States             517
# India                     158
# United Kingdom            133
# Japan                      85
# South Korea                83
# Turkey                     63
# Spain                      28
# Sweden                     20
# Canada                     19
# Italy                      17
# Australia                  17
# China                      17
# France                     17
# Norway                     15
# Thailand                   14
# Iran                       14
# Germany                    13
# Serbia                     12
# Mexico                     12
# Denmark                    11
# Brazil                     10
# Pakistan                    7
# Egypt                       5
# Taiwan                      5
# Ireland                     5
# South Africa                4
# Russia                      4
# Israel                      4
# Belgium                     3
# New Zealand                 3
# Bangladesh                  3
# Colombia                    3
# Poland                      3
# Netherlands                 2
# Indonesia                   2
# Finland                     2
# Iceland                     2
# Portugal                    2
# Singapore                   2
# Chile                       2
# Argentina                   2
# Tunisia                     2
# Bosnia and Herzegovina      1
# Saudi Arabia                1
# Korea                       1
# Croatia                     1
# Estonia                     1
# Latvia                      1
# Jordan                      1
# Romania                     1
# Philippines                 1
# Austria                     1
# Sri Lanka                   1
# Luxembourg                  1
# United Arab Emirates        1
# Name: origin, dtype: int64

# %%
df['made_in_usa'] = (df.origin == 'United States').apply(int)

# %%
df[['imdb_rating', 'made_in_usa']].corr()
# Out:
#              imdb_rating  made_in_usa
# imdb_rating     1.000000    -0.169572
# made_in_usa    -0.169572     1.000000

# %% [markdown]
# ### PRODUCING COMPANY

# %%
from collections import Counter
comp = pd.DataFrame(Counter(df.company.sum()), index=[0]).T
comp[0].sort_values(ascending=False).head(50)
# Out:
# Netflix                                   68
# Amazon Studios                            31
# Studio Dragon                             23
# Universal Television                      21
# CBS Television Studios                    20
# 3 Arts Entertainment                      20
# ABC Signature                             17
# ALTBalaji                                 17
# Warner Bros. Television                   16
# Netflix Studios                           15
# Applause Entertainment Ltd.               15
# Lionsgate Television                      14
# British Broadcasting Corporation (BBC)    14
# BBC Studios                               14
# 20th Television                           11
# JTBC Studios                              11
# Home Box Office (HBO)                     10
# Sony Pictures Television                  10
# MX Player                                 10
# 20th Century Fox Television                9
# Ay Yapim                                   9
# Berlanti Productions                       8
# Paramount Television                       8
# Fox Entertainment                          8
# The Viral Fever                            8
# Contagious Online Media Network            8
# ITV - Independent Television               7
# Zee5                                       7
# Movistar+                                  7
# Broadway Video                             7
# Aniplex                                    7
# Netflix Animation                          7
# GMMTV                                      7
# Studio S                                   6
# CBS Studios                                6
# Warner Bros. Animation                     6
# Jar Pictures                               6
# Boardwalk Pictures                         6
# Amblin Television                          6
# Anonymous Content                          6
# Firefly Productions                        6
# Mappa                                      6
# FX Productions                             6
# DC Entertainment                           6
# tvN Production                             5
# C More                                     5
# Imagine Entertainment                      5
# Nickelodeon Animation Studios              5
# Two Brothers Pictures                      5
# Endeavor Content                           5
# Name: 0, dtype: int64

# %%
#Create list of big companies based on the number of shows produced in the observed time period (minimum of 10 shows)
company_l = ['Netflix', 'Netflix Studios', 'Amazon Studios', 'Studio Dragon', 'Universal Television', 'CBS Television Studios', '3 Arts Entertainment', 'ABC Signature', 'ALTBalaji', 'Warner Bros. Television', ' Applause Entertainment Ltd.', 'Lionsgate Television', 'British Broadcasting Corporation (BBC)', 'BBC Studios', '20th Television', 'JTBC Studios', 'Home Box Office (HBO)', 'Sony Pictures Television', 'MX Player', '20th Century Fox Television', 'Paramount Television', 'Fox Entertainment', 'Netflix Animation', 'Warner Bros. Animation']

def c(x):
    for i in company_l:
        if i in x:
            return 1
        else:
            return 0
    

df['big_c'] = df.company.apply(c)

df[df.big_c==1]
# Out:
#                                        link  imdb_rating  \
# 2      https://www.imdb.com/title/tt8115560          6.6
# 51     https://www.imdb.com/title/tt1312171          8.0
# 86     https://www.imdb.com/title/tt9561862          8.4
# 114    https://www.imdb.com/title/tt9184994          7.9
# 123    https://www.imdb.com/title/tt7087260          7.4
# ...                                     ...          ...
# 1163  https://www.imdb.com/title/tt14163838          6.4
# 1187  https://www.imdb.com/title/tt11834150          7.2
# 1201   https://www.imdb.com/title/tt5540990          6.4
# 1233  https://www.imdb.com/title/tt13278100          7.0
# 1315   https://www.imdb.com/title/tt1267295          6.7
#
#                                 title  s01_episodes  avg_runtime  \
# 2         Tidying Up with Marie Kondo             8           40
# 51               The Umbrella Academy            10           60
# 86               Love, Death & Robots            18           15
# 114   How to Sell Drugs Online (Fast)             6           30
# 123                 Tales of the City            10           60
# ...                               ...           ...          ...
# 1163                  Feels Like Ishq             6           32
# 1187                        The Chair             6           30
# 1201                     On the Verge            12           35
# 1233                        Braqueurs             6           44
# 1315                     Cowboy Bebop            10           58
#
#                            genres   rel_date certification         origin  \
# 2                    [Reality-TV] 2019-01-01         TV-PG  United States
# 51    [Action, Adventure, Comedy] 2019-02-15         TV-14  United States
# 86     [Animation, Short, Action] 2019-03-15         TV-MA  United States
# 114        [Comedy, Crime, Drama] 2019-05-31         TV-MA        Germany
# 123                       [Drama] 2019-06-07         TV-MA  United States
# ...                           ...        ...           ...            ...
# 1163     [Comedy, Drama, Romance] 2021-07-23         TV-MA          India
# 1187              [Comedy, Drama] 2021-08-20         TV-MA  United States
# 1201                     [Comedy] 2021-09-06         TV-14         France
# 1233       [Action, Crime, Drama] 2021-09-24         TV-MA         France
# 1315  [Action, Adventure, Comedy] 2021-11-19         TV-MA  United States
#
#                                                 company  ... Musical Sport  \
# 2                           [Netflix, The Jackal Group]  ...       0     0
# 51    [Dark Horse Entertainment, Netflix, Universal ...  ...       0     0
# 86              [Blur Studio, Netflix Studios, Netflix]  ...       0     0
# 114                         [Bildundtonfabrik, Netflix]  ...       0     0
# 123   [Netflix, Sweetpants Productions, Working Titl...  ...       0     0
# ...                                                 ...  ...     ...   ...
# 1163            [Awesomeness TV, Mutant Films, Netflix]  ...       0     0
# 1187              [BLB Media, Netflix Studios, Netflix]  ...       0     0
# 1201                     [The Film TV, Canal+, Netflix]  ...       0     0
# 1233                        [Labyrinthe Films, Netflix]  ...       0     0
# 1315                 [Midnight Radio, Netflix, Sunrise]  ...       0     0
#
#      Fantasy genres_n  rel_month  TV_PG  TV_14  TV_MA  made_in_usa  big_c
# 2          0        1          1      1      0      0            1      1
# 51         0        3          2      0      1      0            1      1
# 86         0        3          3      0      0      1            1      1
# 114        0        3          5      0      0      1            0      1
# 123        0        1          6      0      0      1            1      1
# ...      ...      ...        ...    ...    ...    ...          ...    ...
# 1163       0        3          7      0      0      1            0      1
# 1187       0        2          8      0      0      1            1      1
# 1201       0        1          9      0      1      0            0      1
# 1233       0        3          9      0      0      1            0      1
# 1315       0        3         11      0      0      1            1      1
#
# [68 rows x 47 columns]

# %%
df['company_n'] = (df.company.apply(lambda x: len(x)))

# %% [markdown]
# AWARDS

# %%
#Calculating the number of awards for each creator and star, and summing them to create a new feature representing the total awards of the show's cast and crew
df['creators_a_n']= df.creators_a.apply(sum) 
df['stars_a_n']= df.stars_a.apply(sum)
df['awards_n'] = df['creators_a_n'] + df['stars_a_n']

df.head()
# Out:
#                                    link  imdb_rating  \
# 0  https://www.imdb.com/title/tt7670568          5.8
# 1  https://www.imdb.com/title/tt8001250          6.2
# 2  https://www.imdb.com/title/tt8115560          6.6
# 3  https://www.imdb.com/title/tt8324422          8.1
# 4  https://www.imdb.com/title/tt8888322          6.6
#
#                          title  s01_episodes  avg_runtime  \
# 0            The Masked Singer            10           60
# 1                Siempre Bruja            11           40
# 2  Tidying Up with Marie Kondo             8           40
# 3                        PEN15            10           30
# 4                        Bloom             6           60
#
#                            genres   rel_date certification         origin  \
# 0  [Game-Show, Music, Reality-TV] 2019-01-02         TV-PG  United States
# 1                [Drama, Fantasy] 2019-01-01         TV-14       Colombia
# 2                    [Reality-TV] 2019-01-01         TV-PG  United States
# 3                        [Comedy] 2019-02-08         TV-MA  United States
# 4        [Drama, Mystery, Sci-Fi] 2019-01-01             0      Australia
#
#                                              company  ... rel_month TV_PG  \
# 0  [Smart Dog Media, Fox Alternative Entertainmen...  ...         1     1
# 1                                          [Caracol]  ...         1     0
# 2                        [Netflix, The Jackal Group]  ...         1     1
# 3  [Awesomeness TV, Odenkirk Provissiero Entertai...  ...         2     0
# 4                                  [Playmaker Media]  ...         1     0
#
#   TV_14 TV_MA  made_in_usa  big_c  company_n  creators_a_n  stars_a_n  \
# 0     0     0            1      0          3             0          9
# 1     1     0            0      0          1             0          0
# 2     0     0            1      1          2             1          1
# 3     0     1            1      0          3             6          7
# 4     0     0            0      0          1             5         12
#
#    awards_n
# 0         9
# 1         0
# 2         2
# 3        13
# 4        17
#
# [5 rows x 51 columns]

# %%
df.corr().iloc[:1]
# Out:
#              imdb_rating  s01_episodes  avg_runtime  Thriller     Music  \
# imdb_rating          1.0      0.036943     0.076961  0.034059  0.014045
#
#                Comedy  Biography  Adventure    Horror  Documentary  ...  \
# imdb_rating  0.022244   0.067982    -0.0017 -0.100276     0.027008  ...
#
#              rel_month     TV_PG     TV_14     TV_MA  made_in_usa     big_c  \
# imdb_rating   0.028357 -0.105924 -0.025684 -0.031788    -0.169572 -0.034374
#
#              company_n  creators_a_n  stars_a_n  awards_n
# imdb_rating  -0.038182      0.001824   0.058789  0.050013
#
# [1 rows x 40 columns]

# %%
#It does not seem interesting to explore particular names as in explored time period only 12 artists manageged to work in more than 3 shows
(pd.Series((df.creators+df.stars).sum()).value_counts() > 3).sum()
# Out:
# 12

# %%
df.columns
# Out:
# Index(['link', 'imdb_rating', 'title', 's01_episodes', 'avg_runtime', 'genres',
#        'rel_date', 'certification', 'origin', 'company', 'creators',
#        'creators_a', 'stars', 'stars_a', 'Thriller', 'Music', 'Comedy',
#        'Biography', 'Adventure', 'Horror', 'Documentary', 'Western', 'Sci_Fi',
#        'Romance', 'Short', 'Mystery', 'Action', 'Family', 'Game_Show', 'News',
#        'Talk_Show', 'War', 'Crime', 'History', 'Drama', 'Reality_TV',
#        'Animation', 'Musical', 'Sport', 'Fantasy', 'genres_n', 'rel_month',
#        'TV_PG', 'TV_14', 'TV_MA', 'made_in_usa', 'big_c', 'company_n',
#        'creators_a_n', 'stars_a_n', 'awards_n'],
#       dtype='object')

# %% [markdown]
# ### pickling shows list to save progress and to follow processing in another notebook

# %%
#df.to_pickle("shows2.pkl")
